# %%
import pandas as pd

# %%
df = pd.read_excel('algorithmsParameters.xlsx', sheet_name='Plan1')
df
# Out:
#      Algorithm                          Model  \
# 0           RF        Random Forest Regressor
# 1           GB    Gradient Boosting Regressor
# 2          SVR       Support Vector Regressor
# 3        Ridge               Ridge Regression
# 4        Lasso               Lasso Regression
# 5   ElasticNet         Elastic Net Regression
# 6          KNN  k-Nearest Neighbors Regressor
# 7     CatBoost             CatBoost Regressor
# 8      XGBoost              XGBoost Regressor
# 9     LightGBM             LightGBM Regressor
# 10        MLP           Multilayer Perceptron
#
#                        Hyperparameters (Search Space)
# 0   n_estimators ∈ {100, 200}; max_depth ∈ {5, 10,...
# 1   n_estimators ∈ {100, 200}; learning_rate ∈ {0....
# 2   C ∈ {0.1, 1, 10, 50}; kernel ∈ {linear, rbf}; ...
# 3                                    α ∈ {0.1, 1, 10}
# 4                   α ∈ {0.01, 0.1, 1}; max_iter=5000
# 5   α ∈ {0.01, 0.1, 1}; l1_ratio ∈ {0.1, 0.5, 0.9}...
# ...

# %%
df.to_csv('algorithmsParameters.csv')
